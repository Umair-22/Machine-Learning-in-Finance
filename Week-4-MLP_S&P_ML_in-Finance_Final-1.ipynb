# %% [markdown]
# <html> <h1 style="font-style:bold; color:blue;"> Machine Learning in Finance </h1> </html>

# %% [markdown]
# <html> <h1 style="font-style:italic; color:blue;"> Week-4 </h1> </html>

# %% [markdown]
# ### Your first price forecast model

# %% [markdown]
# ## S&P-500 Index Prices Forecast using a Multilayer Perceptron (MLP) Neural network

# %% [markdown]
# #### It is a training example of forecasting the S&P 500 Index at the prices of the previous minute of all shares included in this Index. The value of the Index is predicted for the next minute following the current minute.
# #### A multilayer perceptron (MLP) Neural network with fully connected layers (dense) is used.
# #### The dataset consists of the Index (outputs) and stock prices (inputs) for five months of 2017 of the S&P 500 constituents.

# %% [markdown]
# #### The S&P-500 (S&P) is a stock market index that measures the stock performance of 500 large companies listed on stock exchanges in the United States. The weight of each company in the index is proportional to its capitalization (more precisely, free-float)

# %% [markdown]
# #### "S&P-500 Index": (https://en.wikipedia.org/wiki/S%26P_500_Index)

# %% [markdown]
# #### ! Note that this notebook is a hands-on tutorial on machine learning in Finance. Live forecasting of stock prices is a challenging and complex task that requires tremendous effort, especially at higher frequencies, such as the one-minute timeframe used here.

# %% [markdown]
# ##### **Source** - paper "A simple deep learning model for stock price prediction using TensorFlow":
# (https://medium.com/mlreview/a-simple-deep-learning-model-for-stock-price-prediction-using-tensorflow-30505541d877).

# %% [markdown]
# .........................................................![image.png](attachment:d579437e-4c98-4640-89b5-bbf0ace4e99e.png)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# .........................................................![image.png](attachment:6dfa05e1-62da-475a-9373-d120da1dabd2.png)

# %%
np.random.seed(42)

# %% [markdown]
# <html> <h3 style="color:blue;"> Dataset </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:33f6935b-9b68-4b3a-8c28-61aced6a00ce.png)

# %%
data = pd.read_csv('data_stocks.csv')
data.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %% [markdown]
# .........................................................![image.png](attachment:f9ca54a1-19a8-4c70-b638-8234806a1dc1.png)

# %%
data.tail(3)
# Out:
#              DATE    SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 41263  1504209480  2470.03       44.74       164.01      155.065       83.62
# 41264  1504209540  2471.49       44.71       163.88      154.960       83.58
# 41265  1504209600  2471.49       44.74       163.98      155.160       83.69
#
#        NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  \
# 41263      106.52       114.47       47.150       142.33  ...    99.735
# 41264      106.40       114.33       47.135       142.17  ...    99.700
# 41265      106.47       114.46       47.150       142.41  ...    99.670
#
#        NYSE.XEC  NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  \
# 41263     99.64    49.495   40.940    76.315    32.290    62.090     76.88
# 41264     99.63    49.485   40.925    76.300    32.275    62.075     76.83
# 41265     99.64    49.490   40.940    76.320    32.270    62.070     76.81
#
#        NYSE.ZBH  NYSE.ZTS
# 41263    114.31   62.6850
# 41264    114.23   62.6301
# 41265    114.28   62.6800
#
# [3 rows x 502 columns]

# %% [markdown]
# .........................................................![image.png](attachment:19d86cf9-39cc-4860-8ec2-a09a860fc129.png)

# %%
print(data.shape)
data.info()
# Out:
# (41266, 502)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41266 entries, 0 to 41265
# Columns: 502 entries, DATE to NYSE.ZTS
# dtypes: float64(501), int64(1)
# memory usage: 158.0 MB

# %%
# We have 501 float64 and one int64 variables. All data are numerical!

# %% [markdown]
# .........................................................![image.png](attachment:efc952ed-49e8-4898-b733-0cd6b4c5efc3.png)

# %%
data.dtypes
# Out:
# DATE             int64
# SP500          float64
# NASDAQ.AAL     float64
# NASDAQ.AAPL    float64
# NASDAQ.ADBE    float64
#                 ...
# NYSE.XRX       float64
# NYSE.XYL       float64
# NYSE.YUM       float64
# NYSE.ZBH       float64
# NYSE.ZTS       float64
# Length: 502, dtype: object

# %%
# So we actually have 500 shares prices and an Index price for each minute

# %% [markdown]
# .........................................................![image.png](attachment:18e16300-3a0f-436d-8d3c-48638737c299.png)

# %%
plt.figure(num=1, figsize=(15,7))
plt.hist(data['NYSE.XEL'], bins=100)
plt.title('NYSE.XEL price distribution', size=18)
plt.ylabel('Numbers', size=14)
plt.xlabel('Price', size=14)
# Out:
# Text(0.5, 0, 'Price')

# %%
# Guess visually where the support and resistance levels were

# %% [markdown]
# .........................................................![image.png](attachment:ec73b313-3e44-4e56-96f9-64b56e054365.png)

# %%
plt.figure(num=1, figsize=(15,7))
plt.plot(data['SP500']);

# %% [markdown]
# .........................................................![image.png](attachment:ad3190a3-a9c4-476e-9c39-8f0a33ce57b1.png)

# %%
data = data.drop(['DATE'], axis=1)

# %% [markdown]
# .........................................................![image.png](attachment:ff7de325-f0ec-46fa-8733-05707b97c0a9.png)

# %%
data.shape
# Out:
# (41266, 501)

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
# The aim is to forecast the S&P-500 index prices soon (in our example, the S&P-500 price in the next minute). It requires some data preprocessing.
#
# You have to shift the S&P-500 forward one minute so that each row contains the prices of 500 shares in the current minute and the S&P-500 index price in the next minute.
# </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:da1020e8-40ad-49d5-a978-e75343c7490e.png)

# %%
data['SP500']
# Out:
# 0        2363.6101
# 1        2364.1001
# 2        2362.6799
# 3        2364.3101
# 4        2364.8501
#            ...
# 41261    2472.2200
# 41262    2471.7700
# 41263    2470.0300
# 41264    2471.4900
# 41265    2471.4900
# Name: SP500, Length: 41266, dtype: float64

# %% [markdown]
# .........................................................![image.png](attachment:417cb6c7-19cd-484e-ab13-c03ff2206d28.png)

# %%
data['SP500'] = data['SP500'].shift(-1)
data['SP500']
# Out:
# 0        2364.1001
# 1        2362.6799
# 2        2364.3101
# 3        2364.8501
# 4        2365.6201
#            ...
# 41261    2471.7700
# 41262    2470.0300
# 41263    2471.4900
# 41264    2471.4900
# 41265          NaN
# Name: SP500, Length: 41266, dtype: float64

# %%
# You can see that the S&P prices column was shifted up

# %% [markdown]
# .........................................................![image.png](attachment:524e07fa-b517-4139-aed9-3f6f5034dfed.png)

# %%
data = data.dropna(axis=0)
data['SP500']
# Out:
# 0        2364.1001
# 1        2362.6799
# 2        2364.3101
# 3        2364.8501
# 4        2365.6201
#            ...
# 41260    2472.2200
# 41261    2471.7700
# 41262    2470.0300
# 41263    2471.4900
# 41264    2471.4900
# Name: SP500, Length: 41265, dtype: float64

# %% [markdown]
# .........................................................![image.png](attachment:b32bc6bd-8550-48e5-aa64-2828cb8687f1.png)

# %%
data.shape
# Out:
# (41265, 501)

# %%
# Now we have one row less

# %% [markdown]
# .........................................................![image.png](attachment:e8dea7b1-c065-4a07-b0b3-eff78d47db8e.png)

# %%
data_a = np.array(data)

print("data_a:")
print(data_a[:5,:], '\n')
print(data_a[-5,:])
print("type: ", data_a.dtype)
# Out:
# data_a:
# [[2364.1001   42.33    143.68   ...   63.86    122.       53.35  ]
#  [2362.6799   42.36    143.7    ...   63.74    121.77     53.35  ]
#  [2364.3101   42.31    143.6901 ...   63.75    121.7      53.365 ]
#  [2364.8501   42.37    143.64   ...   63.88    121.7      53.38  ]
#  [2365.6201   42.5378  143.66   ...   63.91    121.695    53.24  ]]
#
# [2472.22     44.71    164.14    155.04     83.66    106.63    114.45
#    47.145   142.63     45.13     12.985   177.865   980.02     65.555
#   251.79     29.3     316.       33.22    100.8899  138.75     67.67
#    70.7     398.14     76.9518   40.66    125.96    156.8      32.17
#    50.165   135.07     70.83     78.24     22.215    21.03     57.25
#    79.655   121.41     36.13    468.27     62.85     40.99     56.11
#   148.2      42.68    171.77    119.34    123.79     26.15     38.
#    27.105    27.615    83.53    938.75    954.54     51.56     30.3
#    98.21     12.595    38.62    173.84    155.66    204.1     137.2738
#    46.84     35.075   141.42   1004.24     98.86     80.67     93.62
#    34.62    165.72    103.62     16.22     86.67     40.69     55.8
#    74.8      31.975    31.5      13.195    75.38    174.55     38.66
#    88.54    169.4      13.7      13.365   196.21     57.075    16.715
#    66.315  1851.85     38.53     61.67     52.315    73.15    496.56
#    58.5      54.905    85.66     80.43     10.215    71.83     31.52
#   105.29     29.995    42.775    84.41     59.4925   82.83    220.61
#    28.59     81.14    103.83    160.52     81.49     88.22     41.99
#   148.465   138.985    66.05     56.54     43.67     64.7      97.845
#    75.28     80.26     50.945   130.72     41.35    225.62     59.98
#    73.65     11.045   157.7175   82.61    229.27     60.5      45.36
#    94.86     57.96    116.32     74.69     90.585    78.74     63.24
#   176.83    138.565   147.96     41.04    196.13    139.19     38.85
#    40.91    145.345    80.98    121.42     25.5     187.61     94.18
#    80.85     86.165   176.66    528.05    239.58     23.925    62.06
#    46.17     54.32    319.83    199.59     43.26     53.1      37.5
#    52.34    419.55     39.95     60.45    181.5      27.57     46.445
#   120.55     68.07     32.485    67.51    117.59    141.43     36.065
#    64.03    108.36     69.51     28.995    33.17     50.165     3.635
#   181.91     71.59    138.48     68.32    316.55    159.3625   48.52
#    88.93     29.64     79.65     25.49     41.64    131.12    250.47
#    43.69     16.6      46.42     95.53     31.52     19.77     77.39
#   107.56    111.04     78.8      47.2      84.68    115.94     58.98
#    72.49    108.33     36.215    83.565   101.27     96.445   118.2
#    84.86     66.07     90.95     82.21    112.32     87.28     58.6
#    31.41     84.97    133.28     84.235   142.54     80.205   106.94
#    86.28     59.04     84.93     67.1      62.265    62.99    265.76
#    71.795    79.25     52.35    113.67     37.85     77.62     11.06
#    62.54     14.79    214.49     32.58     92.97     35.14     38.6
#    39.26     86.27    126.87     25.835    65.02    201.52     24.59
#    20.75     53.32     28.785    36.51     82.82     95.55     23.615
#   224.11    162.56     38.975    24.29     78.655    73.27     29.8075
#   149.98     38.87     54.065    46.95    138.16     42.35     18.07
#    19.11     26.72     30.725   122.83     18.135   104.96    257.3125
#   143.12     64.67    136.77     53.885    20.125    85.43     39.37
#   120.71    137.5      32.8      39.515    54.52    132.385    27.75
#    90.99     44.6      65.505    17.235    19.63    123.19     19.34
#    67.13     45.535    42.175    21.85     39.84    103.37     46.56
#    36.25     46.       51.7725  156.94    181.52     81.22    305.47
#    67.88     42.75     74.08     23.71     52.15     54.47     90.54
#    20.81    133.55    106.49     52.79     36.79    159.97    149.45
#   134.16     80.66     46.86    253.08     95.155   211.89     78.07
#   204.26     45.9      63.505   117.25     19.95     52.39     63.85
#    11.14     45.55     88.09    148.01     27.13     23.7675  150.53
#    38.285    26.135    26.865    52.8      38.8275  272.1      30.61
#    24.935   120.525    55.09     48.3      57.5      54.24     72.28
#    50.48     59.78     70.395    46.925   115.82     33.965    62.6
#    92.32     46.47    160.82     25.83     67.01     63.37    116.97
#   125.41     62.04     89.98    104.18     39.25     78.92    102.18
#   205.04     83.73    125.86     35.96    131.55    129.75     65.69
#   124.36     64.29     14.14     45.31    107.5925    8.69     78.41
#    87.87    164.2     230.805    17.34     65.26    181.995    60.365
#    39.92     44.35    338.88     63.16    104.85     63.56     96.39
#   147.54     48.24    156.88    154.38    117.95     55.12     92.53
#   200.23    144.19     30.82    141.56     52.71     37.55     89.76
#   260.708    79.62     54.545    91.37     72.4      77.02    187.315
#   121.23     63.43     99.54     69.21    101.1      49.11     15.11
#    16.125    61.95     38.785   108.29    199.45     48.21    105.3125
#   114.39    118.0268   51.24    119.79    103.7     106.16     62.87
#    68.14    121.39     74.58     68.39     48.01    183.36     65.22
#    51.06    171.72     77.16     29.75     78.105    56.9      18.92
#    32.675    99.66     99.49     49.495    40.975    76.4      32.295
#    62.095    76.885   114.3      62.73  ]
# type:  float64

# %% [markdown]
# .........................................................![image.png](attachment:ed172b0d-bac6-45ea-a33a-b68014f00608.png)

# %%
data = []
data
# Out:
# []

# %% [markdown]
# <html> <h3 style="color:blue;"> Data for training and testing </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:b1fb582e-7b59-45f7-904b-2f63f42fce26.png)

# %%
n = data_a.shape[0]
train_start = 0
train_end = int(np.floor(0.8*n))
print(train_end)
# Out:
# 33012

# %% [markdown]
# .........................................................![image.png](attachment:e92704ea-cb4a-4b30-9411-11a9535c65bf.png)

# %%
train_end -= 12
print(train_end)
# Out:
# 33000

# %% [markdown]
# .........................................................![image.png](attachment:65cd57f0-b4c6-49e0-91bd-828e0f1e34bd.png)

# %%
test_start = train_end
train_end = n

data_train = data_a[np.arange(train_start, train_end), :]
data_test = data_a[np.arange(train_start, train_end), :]

# %% [markdown]
# .........................................................![image.png](attachment:f822633d-115a-49cc-957a-cb782ce04440.png)

# %%
print('Data for training: ', data_train.shape)
print('Data for testing: ', data_test.shape)
# Out:
# Data for training:  (41265, 501)
# Data for testing:  (41265, 501)

# %% [markdown]
# .........................................................![image.png](attachment:8ef74910-a136-46dd-a90a-47d01ca91453.png)

# %%
data_a = []
data_a
# Out:
# []

# %% [markdown]
# <html> <h3 style="color:blue;"> Data normalisation </h3> </html>

# %% [markdown]
# ![image.png](attachment:da48fee3-b725-4785-816b-f531b7c65328.png)

# %% [markdown]
# .........................................................![image.png](attachment:70f276d6-f087-420a-bf84-2c0ce58b3f51.png)

# %%
from sklearn.preprocessing import MinMaxScaler 
scaler = MinMaxScaler()

# %% [markdown]
# <html> <h3 style="color:red;"> !!! Note: </h3> </html>
#
# <html> <h3 style="font-style:italic; color:blue;">
#
# A typical mistake when choosing a part of the data and time for scaling is to scale the entire dataset before dividing it into test and training data. It is a mistake because scaling starts the calculation of statistics, that is, minima/maxima of variables. When realising time series forecasting in real life, at the time of their generation, you cannot have information from observations in the future.
#
# Therefore, statistics should be calculated on the training data, and then the result should be applied to the test data. Otherwise, by taking information “from the future” to generate predictions (that is, from a test sample), the model will produce forecasts with “system bias.”
#
# </h3> </html>

# %% [markdown]
# .........................................................![image.png](attachment:0854ac19-9b7a-43c5-90bd-c8eebdb64e12.png)

# %%
scaler.fit(data_train)

data_train_norm = scaler.transform(data_train)
data_test_norm = scaler.transform(data_test)

# %% [markdown]
# .........................................................![image.png](attachment:a802084b-2fa3-442d-9458-3e76dbe41412.png)

# %%
print(data_train_norm.min())
print(data_train_norm.max(), '\n')

print(data_test_norm.min())
print(data_test_norm.max())
# Out:
# 0.0
# 1.0000000000000018
#
# 0.0
# 1.0000000000000018

# %% [markdown]
# The first two numbers above mean that all columns (stock prices and S&P index price) are normalised in the range [0,1].
# In this case, the normalisation occurs for each column separately.
#
# The following two numbers mean that there are stocks (not necessarily all of them) whose prices changed during the last 20% period (test dataset) in broader ranges than they changed during the first 80% period (training dataset).
#
# It is acceptable that after normalisation, some stocks go beyond the range [0,1] since they still are in the same order with this range.

# %% [markdown]
# <html> <h3 style="color:blue;"> A matrix of input parameters and an output vector for training and test datasets </h3> </html>

# %%
# create two data sets: 
# for training: (X_train, y_train)
# and for tests: (X_test, y_test)

# X_train and X_test are matrixes with 1-minute time-frame prices of 500 stocks
# y_train and y_test are S&P-500 values in the next minute

# %% [markdown]
# .........................................................![image.png](attachment:image.png)

# %%
X_train = data_train_norm[:, 1:]
y_train = data_train_norm[:, 0]

X_test = data_test_norm[:, 1:]
y_test = data_test_norm[:, 0]

# %% [markdown]
# .........................................................![image.png](attachment:21772b3c-cdf1-414c-936a-8775e186df88.png)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (41265, 500)
# (41265,)
# (41265, 500)
# (41265,)

# %% [markdown]
# <html> <h2 style="color:blue;"> Neural Network (Multilayer Perceptron - MLP) </h2> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
# import TensorFlow and Keras

import tensorflow as tf
from tensorflow import keras

# %%
# If you have a problem with TensorFlow import as shown above,
# you have to install TensorFlow:
# Otherwise, please ignore the next two cells

# %%
pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in c:\users\smart tech\appdata\roaming\python\python312\site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting tensorflow-intel==2.18.0 (from tensorflow)
#   Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl.metadata (4.9 kB)
# Collecting absl-py>=1.0.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Collecting opt-einsum>=2.3.2 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached grpcio-1.67.0-cp312-cp312-win_amd64.whl.metadata (4.0 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.5.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.11.0)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow-intel==2.18.0->tensorflow)
#   Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\programdata\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\smart tech\appdata\roaming\python\python312\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\programdata\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.0)
# Using cached tensorflow-2.18.0-cp312-cp312-win_amd64.whl (7.5 kB)
# Using cached tensorflow_intel-2.18.0-cp312-cp312-win_amd64.whl (390.3 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Using cached grpcio-1.67.0-cp312-cp312-win_amd64.whl (4.3 MB)
# Using cached keras-3.6.0-py3-none-any.whl (1.2 MB)
# Using cached ml_dtypes-0.4.1-cp312-cp312-win_amd64.whl (127 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Installing collected packages: opt-einsum, ml-dtypes, grpcio, google-pasta, gast, astunparse, absl-py, tensorboard, keras, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 gast-0.6.0 google-pasta-0.2.0 grpcio-1.67.0 keras-3.6.0 ml-dtypes-0.4.1 opt-einsum-3.4.0 tensorboard-2.18.0 tensorflow-2.18.0 tensorflow-intel-2.18.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tensorboard.exe is installed in 'C:\Users\SMART TECH\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\SMART TECH\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %% [markdown]
# <html> <h3 style="color:red;"> !! restart the kernel </h3> </html>

# %% [markdown]
# ![image.png](attachment:b04a62f9-085a-48d9-a343-e3db3d973895.png)

# %%
# Run import TensoFlow after installing

# %%
# import TensorFlow and Keras

import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# .........................................................![image.png](attachment:f5b7278f-8f96-4088-bfc6-637544188dca.png)

# %%
print(tf.__version__)
# Out:
# 2.18.0

# %% [markdown]
# <html> <h4 style="color:blue;">
#
# The Multilayer Perceptron architecture:
#
# Number of input neurons = Number of stocks for training = 500
# - Model (Neural network) consists of 4 hidden levels:
#  - The first contains 1024 neurons, which is slightly more than twice the amount of input data
#  - The subsequent hidden levels are half the previous level: 512, 256 and 128 neurons
#  - Reducing the number of neurons at each level compresses the information that the network processed at previous levels
#  - output layer - ONE neuron (predicted S&P price) as this is a regression task
#
# </h4> </html>

# %% [markdown]
# .........................................................![image.png](attachment:image.png)

# %%
model = keras.Sequential([

# activation function = "relu",
# initial weights are initialised randomly using normal distribution
keras.layers.Dense(1024, input_dim=500, activation=tf.nn.relu, kernel_initializer="normal"),

keras.layers.Dense(512, activation='relu', kernel_initializer="normal"),

keras.layers.Dense(256, activation='relu', kernel_initializer="normal"),

keras.layers.Dense(128, activation='relu', kernel_initializer="normal"),

# Output Layer: 1-neuron - the answer is the price of S & P-500 in the next minute
keras.layers.Dense(1)
])
print(model.summary())
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 1024)           │       513,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,202,177 (4.59 MB)
#  Trainable params: 1,202,177 (4.59 MB)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# .........................................................![image.png](attachment:11f3c506-2886-4aef-bae0-575428f41234.png)

# %%
model. compile(optimizer="adam", loss="mse", metrics=["mae"])

# %% [markdown]
# <html> <h3 style="color:blue;"> Training the Neural Network </h3> </html>

# %% [markdown]
# ![image.png](attachment:0624706f-5ef9-4a1c-9eaf-4d1a55a4377a.png)

# %% [markdown]
# #### <font color='red'>!!! If neural network training is slow and you spend more than one minute on one epoch, restart the Kernel, reduce the number of epochs to 10, and run again.</font>

# %% [markdown]
# .................![image.png](attachment:21332a6e-e620-42d2-b956-1adf03b3d734.png)

# %%
# Validation_split = 0.2 - the part of the training dataset that is used for validation and checking overfitting start
# verbose = 1 - demonstrate the training process

history = model. fit(X_train, y_train, batch_size=10, epochs=20, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 37s 10ms/step - loss: 0.0185 - mae: 0.0352 - val_loss: 0.0030 - val_mae: 0.0461
# Epoch 2/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 3.4011e-04 - mae: 0.0138 - val_loss: 0.0106 - val_mae: 0.0893
# Epoch 3/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 1.7398e-04 - mae: 0.0101 - val_loss: 0.0122 - val_mae: 0.0996
# Epoch 4/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 1.0427e-04 - mae: 0.0078 - val_loss: 0.0113 - val_mae: 0.0950
# Epoch 5/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 33s 10ms/step - loss: 9.3605e-05 - mae: 0.0074 - val_loss: 0.0112 - val_mae: 0.0947
# Epoch 6/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 8.8086e-05 - mae: 0.0071 - val_loss: 0.0117 - val_mae: 0.0981
# Epoch 7/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 6.9272e-05 - mae: 0.0064 - val_loss: 0.0094 - val_mae: 0.0854
# Epoch 8/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 6.2618e-05 - mae: 0.0061 - val_loss: 0.0140 - val_mae: 0.1095
# Epoch 9/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 5.9290e-05 - mae: 0.0058 - val_loss: 0.0096 - val_mae: 0.0871
# Epoch 10/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 5.2518e-05 - mae: 0.0055 - val_loss: 0.0097 - val_mae: 0.0872
# Epoch 11/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 36s 11ms/step - loss: 5.3730e-05 - mae: 0.0056 - val_loss: 0.0118 - val_mae: 0.0984
# Epoch 12/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 4.7427e-05 - mae: 0.0052 - val_loss: 0.0113 - val_mae: 0.0965
# Epoch 13/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 34s 10ms/step - loss: 4.7672e-05 - mae: 0.0052 - val_loss: 0.0141 - val_mae: 0.1100
# Epoch 14/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 5.0504e-05 - mae: 0.0054 - val_loss: 0.0137 - val_mae: 0.1086
# Epoch 15/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 4.3066e-05 - mae: 0.0049 - val_loss: 0.0114 - val_mae: 0.0976
# Epoch 16/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 4.4595e-05 - mae: 0.0050 - val_loss: 0.0125 - val_mae: 0.1027
# Epoch 17/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 4.2787e-05 - mae: 0.0049 - val_loss: 0.0133 - val_mae: 0.1069
# Epoch 18/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 10ms/step - loss: 4.1617e-05 - mae: 0.0048 - val_loss: 0.0098 - val_mae: 0.0890
# Epoch 19/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 35s 11ms/step - loss: 4.1621e-05 - mae: 0.0049 - val_loss: 0.0099 - val_mae: 0.0892
# Epoch 20/20
# 3302/3302 ━━━━━━━━━━━━━━━━━━━━ 36s 11ms/step - loss: 4.6385e-05 - mae: 0.0051 - val_loss: 0.0091 - val_mae: 0.0852

# %% [markdown]
# <html> <h3 style="color:blue;"> Evaluation </h3> </html>

# %% [markdown]
# ................................................![image.png](attachment:ba00113a-5d6b-4834-9fdf-52f99e40d12b.png)

# %%
mse, mae = model. evaluate(X_test, y_test, verbose=0)

print("Mean absolute error: %.5f" % mae)
print("Mean squared error: %.5f" % mse)
# Out:
# Mean absolute error: 0.02386
# Mean squared error: 0.00190

# %% [markdown]
# <html> <h3 style="color:blue;"> Training process graph </h3> </html>

# %% [markdown]
# #### Mean Absolute Error (MAE) Chart

# %% [markdown]
# ##### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
history_dict = history.history

mean_absolute_error_values = history_dict['mae']
val_mean_absolute_error_values = history_dict['val_mae']
epochs = range(1, len(mean_absolute_error_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mean_absolute_error_values, 'bo', label='Training mae')
plt.plot(epochs, val_mean_absolute_error_values, 'b', label='Validation mae')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error - mae')
plt.legend()
plt.show()

# %% [markdown]
# ##### Type the code below by copying and slightly changing the previous cell code

# %% [markdown]
# ...................................![image.png](attachment:7e2e3e88-3c3f-40cd-905a-c831d2f67777.png)

# %%
history_dict = history.history

mean_absolute_error_values = history_dict['loss']
val_mean_absolute_error_values = history_dict['val_loss']
epochs = range(1, len(mean_absolute_error_values) + 1)

plt.figure(num=1, figsize=(15,7))
plt.plot(epochs, mean_absolute_error_values, 'bo', label='Training mse')
plt.plot(epochs, val_mean_absolute_error_values, 'b', label='Validation mse')
plt.xlabel('Epochs')
plt.ylabel('Mean Squared Error - mse')
plt. legend()
plt.show()

# %% [markdown]
# <html> <h3 style="color:blue;"> Using the neural network to predict the price of the S&P-500 </h3> </html>

# %%
# Based on the MinMaxScaler formula, let's calculate the parameters for restoring absolute prices from normalised ones.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ...................................![image.png](attachment:56332b8c-142f-4b48-ad7e-6931c35b8eaa.png)

# %%
sp500_min_train_min = data_train[:,0].min()
sp500_min_train_max = data_train[:, 0].max()

print(sp500_min_train_min, '\n',
sp500_min_train_max)
# Out:
# 2329.1399
#  2490.6499

# %% [markdown]
# ........................................![image.png](attachment:b7cdf473-7fb0-4812-bad1-b54c1845a42b.png)

# %%
sp500_min_train_delta = data_train[:,0].max() - data_train[:,0].min()
sp500_min_train_delta
# Out:
# 161.50999999999976

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
import random

pred = model.predict(X_test)

n_rec = random.randint(0, X_test.shape[0])

predicted_price = pred[n_rec][0] * sp500_min_train_delta + sp500_min_train_min
actual_price    = y_test[n_rec]  * sp500_min_train_delta + sp500_min_train_min

print(" Predicted price:", predicted_price, '\n' , 
      "Actual price:", actual_price, '\n', 
      "absolut error:", predicted_price - actual_price, '\n',
      "% absolut error:", (predicted_price - actual_price) / actual_price * 100,"%")
# Out:
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
#  Predicted price: 2445.695844867134
#  Actual price: 2448.26
#  absolut error: -2.56415513286629
#  % absolut error: -0.1047337755330843 %

# %%
import random

# Run the prediction multiple times
for _ in range(5):  # Change the range for more iterations
    n_rec = random.randint(0, X_test.shape[0] - 1)  # Select a random index
    
    pred = model.predict(X_test)  # Get predictions

    predicted_price = pred[n_rec][0] * sp500_min_train_delta + sp500_min_train_min
    actual_price    = y_test[n_rec] * sp500_min_train_delta + sp500_min_train_min

    absolute_error = predicted_price - actual_price
    percentage_error = (absolute_error / actual_price) * 100

    print("Predicted price:", predicted_price, 
          "\nActual price:", actual_price, 
          "\nAbsolute error:", absolute_error, 
          "\n% Absolute error:", percentage_error, "%\n")
# Out:
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step
# Predicted price: 2396.2433412065147
# Actual price: 2397.98
# Absolute error: -1.736658793485276
# % Absolute error: -0.07242173802472397 %
#
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step
# Predicted price: 2472.792035545015
# Actual price: 2472.3701
# Absolute error: 0.4219355450150033
# % Absolute error: 0.017066034936072203 %
#
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step
# Predicted price: 2469.0233088176487
# Actual price: 2448.49
# Absolute error: 20.533308817648958
# % Absolute error: 0.838611095722219 %
#
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step
# Predicted price: 2388.2819932373404
# Actual price: 2388.3601000000003
# Absolute error: -0.07810676265989969
# % Absolute error: -0.00327030930804361 %
#
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step
# Predicted price: 2473.3455638234855
# Actual price: 2475.0801
# Absolute error: -1.7345361765146663
# % Absolute error: -0.07008000171447648 %

# %% [markdown]
# <html> <h3 style="font-style:italic; color:red;">
# Run the previous cell several times and look at the results
# </h3> </html>
#
#
# <html> <h3 style="color:blue;">Describe the results in the cell below </h3> </html>

# %% [markdown]
# <html> <h3 style="color:blue;"> Price chart </h3> </html>

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
fig = plt.figure(figsize=(17,6)) 
ax1 = fig.add_subplot(111)
line1, = ax1.plot(y_test * sp500_min_train_delta + sp500_min_train_min)
line2, = ax1.plot(pred[:,0] * sp500_min_train_delta + sp500_min_train_min)
plt.legend(labels=['Actual prices', 'Predicted prices'], loc='upper right')

plt.show();

# %% [markdown]
# <html> <h3 style="color:blue;"> Error Chart </h3> </html>

# %%
# Shows the absolute error in predicting the SP values ​​at each minute.

# %% [markdown]
# #### Now just press 'CTRL' and 'ENTER' keys on the next cells.

# %%
plt.ion()  # interactive mode, used for graphs of many functions 
# More details: https://www.geeksforgeeks.org/matplotlib-pyplot-ion-in-python/

fig = plt.figure(figsize=(17,6)) 
ax1 = fig.add_subplot(111)

a = (pred[:,0]-y_test) * sp500_min_train_delta
line1, = ax1.plot(a)

plt.show()

# %%
# Further improvement of the predictive system should be aimed at reducing the outliers on the graph.

# %% [markdown]
# # Lab Logbook Requirement:

# %% [markdown]
# <html> <h3 style="font-style:italic; color:blue;">
#
# 1) Create your own Multi-layer Perceptron (MLP) with two hidden layers, where the first hidden layer cells' number equals the last three digits of your SID. The number of cells in the next hidden layer is approximately two times smaller. For example, if your SID is 2287167, the number of cells on the first hidden layer is 167, and on the second - 84. Take epochs=10. Leave other parameters the same as in the practical session.
# 2) Compile the model.
# 3) Train your MLP with the same datasets and demonstrate the received MAE.
# 4) Compare your MAE with the MAE of the MLP in the practical session.
# 5) Please only add to your Lab Logbook a print-screen of your MLP architecture using model.summary() and the resulting MAE.
#
# </h3> </html>

# %% [markdown]
# <html> <h3 style="color:red;">
# NOTE: DON'T FORGET TO SAVE AND BACK UP YOUR COMPLETED JUPYTER NOTEBOOK AND LAB LOGBOOK ON GITHUB OR ONEDRIVE.
# </h3> </html>

# %%
from sklearn.metrics import mean_absolute_error

# SID is 2372735
last_three_digits = 735  # 735 from the last three digits of SID
second_layer_cells = last_three_digits // 2  # Approximately half

# Create the MLP model
model = keras.Sequential([
    keras.layers.Dense(last_three_digits, activation='relu', input_shape=(500,), kernel_initializer="normal"),
    keras.layers.Dense(second_layer_cells, activation='relu', kernel_initializer="normal"),
    keras.layers.Dense(1)  # Output layer for regression
])

# Compile the model
model.compile(optimizer='adam', loss='mean_absolute_error')

# Train the model (replace X_train and y_train with your training data)
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Predict on test data (replace X_test with your test data)
predictions = model.predict(X_test)

# Calculate MAE
mae = mean_absolute_error(y_test, predictions)

# Print the model summary
model.summary()

# Print the resulting MAE
print("Mean Absolute Error (MAE):", mae)
# Out:
# Epoch 1/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 0.0915
# Epoch 2/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0132
# Epoch 3/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0104
# Epoch 4/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0099
# Epoch 5/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0082
# Epoch 6/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0069
# Epoch 7/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0070
# Epoch 8/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0067
# Epoch 9/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 0.0058
# Epoch 10/10
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 0.0061
# 1290/1290 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                │ (None, 735)            │       368,235 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 367)            │       270,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 1)              │           368 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,916,147 (7.31 MB)
#  Trainable params: 638,715 (2.44 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,277,432 (4.87 MB)
# Mean Absolute Error (MAE): 0.0044932929360251665
